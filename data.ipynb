# %%
import random
from datetime import datetime, timedelta
import json

turning_points = [
    {"latitude": 23.1283, "longitude": 72.54244},
    {"latitude": 23.12811, "longitude": 72.54244},
    {"latitude": 23.12812, "longitude": 72.54264},
    {"latitude": 23.12812, "longitude": 72.54283},
    {"latitude": 23.12761, "longitude": 72.54283},
    {"latitude": 23.12725, "longitude": 72.54283},
    {"latitude": 23.12726, "longitude": 72.54316},
    {"latitude": 23.12726, "longitude": 72.54429},
    {"latitude": 23.12726, "longitude": 72.54527},
    {"latitude": 23.12726, "longitude": 72.54559},
    {"latitude": 23.12725, "longitude": 72.54598},
    {"latitude": 23.12751, "longitude": 72.54598},
    {"latitude": 23.12788, "longitude": 72.54599},
    {"latitude": 23.12817, "longitude": 72.54599},
    {"latitude": 23.1285, "longitude": 72.54599},
    {"latitude": 23.1285, "longitude": 72.54658},
    {"latitude": 23.12851, "longitude": 72.5474},
    {"latitude": 23.12851, "longitude": 72.54744},
    {"latitude": 23.12828, "longitude": 72.54744}
]

def random_coordinate(point1, point2):
    latitude = round(random.uniform(min(point1["latitude"], point2["latitude"]), max(point1["latitude"], point2["latitude"])), 5)
    longitude = round(random.uniform(min(point1["longitude"], point2["longitude"]), max(point1["longitude"], point2["longitude"])), 5)
    return latitude, longitude

def random_timestamp():
    base_time = datetime(2024, 10, 31, 12, 0)
    delta = timedelta(hours=random.randint(0, 48))
    return (base_time + delta).isoformat()

def generate_data():
    start_index = random.randint(0, len(turning_points) - 2)
    point1 = turning_points[start_index]
    point2 = turning_points[start_index + 1]
    
    latitude, longitude = random_coordinate(point1, point2)

    data = {
        "WLSU_ID": str(random.randint(10000, 99999)),
        "CLUSTER_ID": str(random.randint(1000, 9999)),
        "data_history": [
                {
                        "AQI": str(random.randint(40, 150)),
                        "ISD": str(random.randint(20, 50)),
                        "SQI": str(random.randint(60, 100)),
                        "timestamp": random_timestamp(),
                        "VL": str(random.randint(70, 100)),
                        "WLL": str(random.randint(80, 100))
                    
                },
                               {
                        "AQI": str(random.randint(40, 150)),
                        "ISD": str(random.randint(20, 50)),
                        "SQI": str(random.randint(60, 100)),
                        "timestamp": random_timestamp(),
                        "VL": str(random.randint(70, 100)),
                        "WLL": str(random.randint(80, 100))
                    
                },
                               {
                        "AQI": str(random.randint(40, 150)),
                        "ISD": str(random.randint(20, 50)),
                        "SQI": str(random.randint(60, 100)),
                        "timestamp": random_timestamp(),
                        "VL": str(random.randint(70, 100)),
                        "WLL": str(random.randint(80, 100))
                    
                },
             ],
        "L1N1": [f"{latitude}",f"{longitude}"]
        ,
        "STATUS": random.choice([True, False]),
        "TIMESTAMP": random_timestamp(),
        "WLSU_NAME": f"WLSU_{random.randint(1, 100)}"
    }
    return data

# Generate 20 data entries
sample_data = [generate_data() for _ in range(20)]

# %%
sample_data
# Out:
# [{'WLSU_ID': '25938',
#   'CLUSTER_ID': '3117',
#   'data_history': [{'AQI': '104',
#     'ISD': '22',
#     'SQI': '90',
#     'timestamp': '2024-11-02T10:00:00',
#     'VL': '87',
#     'WLL': '85'},
#    {'AQI': '141',
#     'ISD': '36',
#     'SQI': '70',
#     'timestamp': '2024-11-02T00:00:00',
#     'VL': '77',
#     'WLL': '91'},
#    {'AQI': '122',
#     'ISD': '20',
#     'SQI': '68',
#     'timestamp': '2024-10-31T15:00:00',
#     'VL': '76',
#     'WLL': '82'}],
#   'L1N1': ['23.12837', '72.54599'],
#   'STATUS': True,
#   'TIMESTAMP': '2024-11-01T03:00:00',
#   'WLSU_NAME': 'WLSU_94'},
#  {'WLSU_ID': '98446',
#   'CLUSTER_ID': '1552',
#   'data_history': [{'AQI': '41',
#     'ISD': '37',
#     'SQI': '85',
#     'timestamp': '2024-10-31T22:00:00',
#     'VL': '82',
#     'WLL': '93'},
#    {'AQI': '113',
#     'ISD': '22',
#     'SQI': '67',
#     'timestamp': '2024-11-01T17:00:00',
#     'VL': '98',
#     'WLL': '92'},
#    {'AQI': '120',
#     'ISD': '44',
#     'SQI': '80',
#     'timestamp': '2024-11-01T03:00:00',
#     'VL': '72',
#     'WLL': '90'}],
#   'L1N1': ['23.12812', '72.54276'],
#   'STATUS': False,
#   'TIMESTAMP': '2024-10-31T18:00:00',
#   'WLSU_NAME': 'WLSU_41'},
#  {'WLSU_ID': '99532',
#   'CLUSTER_ID': '7401',
#   'data_history': [{'AQI': '91',
#     'ISD': '33',
#     'SQI': '82',
#     'timestamp': '2024-11-01T01:00:00',
#     'VL': '72',
#     'WLL': '86'},
#    {'AQI': '142',
#     'ISD': '49',
#     'SQI': '66',
#     'timestamp': '2024-10-31T20:00:00',
#     'VL': '87',
#     'WLL': '90'},
#    {'AQI': '121',
#     'ISD': '39',
#     'SQI': '96',
#     'timestamp': '2024-11-01T09:00:00',
#     'VL': '74',
#     'WLL': '94'}],
#   'L1N1': ['23.12851', '72.54716'],
#   'STATUS': True,
#   'TIMESTAMP': '2024-11-01T09:00:00',
#   'WLSU_NAME': 'WLSU_83'},
#  {'WLSU_ID': '55286',
#   'CLUSTER_ID': '9661',
#   'data_history': [{'AQI': '94',
#     'ISD': '33',
#     'SQI': '93',
#     'timestamp': '2024-11-01T23:00:00',
#     'VL': '96',
#     'WLL': '95'},
#    {'AQI': '136',
#     'ISD': '33',
#     'SQI': '96',
#     'timestamp': '2024-10-31T15:00:00',
#     'VL': '85',
#     'WLL': '82'},
#    {'AQI': '86',
#     'ISD': '50',
#     'SQI': '78',
#     'timestamp': '2024-11-01T04:00:00',
#     'VL': '97',
#     'WLL': '81'}],
#   'L1N1': ['23.12755', '72.54599'],
#   'STATUS': False,
#   'TIMESTAMP': '2024-10-31T21:00:00',
#   'WLSU_NAME': 'WLSU_19'},
#  {'WLSU_ID': '98481',
#   'CLUSTER_ID': '6522',
#   'data_history': [{'AQI': '147',
#     'ISD': '33',
#     'SQI': '79',
#     'timestamp': '2024-11-01T10:00:00',
#     'VL': '91',
#     'WLL': '83'},
#    {'AQI': '126',
#     'ISD': '25',
#     'SQI': '65',
#     'timestamp': '2024-11-01T15:00:00',
#     'VL': '76',
#     'WLL': '89'},
#    {'AQI': '114',
#     'ISD': '31',
#     'SQI': '62',
#     'timestamp': '2024-11-01T15:00:00',
#     'VL': '84',
#     'WLL': '90'}],
#   'L1N1': ['23.12726', '72.54434'],
#   'STATUS': True,
#   'TIMESTAMP': '2024-11-01T22:00:00',
#   'WLSU_NAME': 'WLSU_88'},
#  {'WLSU_ID': '23892',
#   'CLUSTER_ID': '2575',
#   'data_history': [{'AQI': '98',
#     'ISD': '45',
#     'SQI': '63',
#     'timestamp': '2024-11-02T05:00:00',
#     'VL': '83',
#     'WLL': '88'},
#    {'AQI': '103',
#     'ISD': '49',
#     'SQI': '97',
#     'timestamp': '2024-11-01T19:00:00',
#     'VL': '82',
#     'WLL': '91'},
#    {'AQI': '77',
#     'ISD': '47',
#     'SQI': '71',
#     'timestamp': '2024-10-31T13:00:00',
#     'VL': '70',
#     'WLL': '80'}],
#   'L1N1': ['23.12726', '72.5458'],
#   'STATUS': True,
#   'TIMESTAMP': '2024-10-31T17:00:00',
#   'WLSU_NAME': 'WLSU_28'},
#  {'WLSU_ID': '75567',
#   'CLUSTER_ID': '9535',
#   'data_history': [{'AQI': '97',
#     'ISD': '42',
#     'SQI': '62',
#     'timestamp': '2024-11-01T15:00:00',
#     'VL': '91',
#     'WLL': '95'},
#    {'AQI': '65',
#     'ISD': '23',
#     'SQI': '64',
#     'timestamp': '2024-11-02T04:00:00',
#     'VL': '88',
#     'WLL': '91'},
#    {'AQI': '123',
#     'ISD': '24',
#     'SQI': '84',
#     'timestamp': '2024-11-01T02:00:00',
#     'VL': '86',
#     'WLL': '80'}],
#   'L1N1': ['23.12835', '72.54744'],
#   'STATUS': True,
#   'TIMESTAMP': '2024-11-01T16:00:00',
#   'WLSU_NAME': 'WLSU_50'},
#  {'WLSU_ID': '53224',
#   'CLUSTER_ID': '4265',
#   'data_history': [{'AQI': '72',
#     'ISD': '25',
#     'SQI': '90',
#     'timestamp': '2024-11-01T19:00:00',
#     'VL': '95',
#     'WLL': '81'},
#    {'AQI': '69',
#     'ISD': '50',
#     'SQI': '87',
#     'timestamp': '2024-10-31T18:00:00',
#     'VL': '73',
#     'WLL': '96'},
#    {'AQI': '71',
#     'ISD': '26',
#     'SQI': '70',
#     'timestamp': '2024-11-01T11:00:00',
#     'VL': '82',
#     'WLL': '90'}],
#   'L1N1': ['23.12811', '72.54246'],
#   'STATUS': False,
#   'TIMESTAMP': '2024-11-02T05:00:00',
#   'WLSU_NAME': 'WLSU_70'},
#  {'WLSU_ID': '56032',
#   'CLUSTER_ID': '1293',
#   'data_history': [{'AQI': '114',
#     'ISD': '44',
#     'SQI': '96',
#     'timestamp': '2024-10-31T21:00:00',
#     'VL': '97',
#     'WLL': '97'},
#    {'AQI': '100',
#     'ISD': '43',
#     'SQI': '100',
#     'timestamp': '2024-11-01T23:00:00',
#     'VL': '83',
#     'WLL': '95'},
#    {'AQI': '71',
#     'ISD': '25',
#     'SQI': '87',
#     'timestamp': '2024-11-01T08:00:00',
#     'VL': '86',
#     'WLL': '90'}],
#   'L1N1': ['23.12812', '72.54266'],
#   'STATUS': False,
#   'TIMESTAMP': '2024-11-01T03:00:00',
#   'WLSU_NAME': 'WLSU_67'},
#  {'WLSU_ID': '95840',
#   'CLUSTER_ID': '4429',
#   'data_history': [{'AQI': '117',
#     'ISD': '43',
#     'SQI': '89',
#     'timestamp': '2024-10-31T13:00:00',
#     'VL': '95',
#     'WLL': '89'},
#    {'AQI': '96',
#     'ISD': '28',
#     'SQI': '92',
#     'timestamp': '2024-10-31T18:00:00',
#     'VL': '94',
#     'WLL': '84'},
#    {'AQI': '58',
#     'ISD': '24',
#     'SQI': '97',
#     'timestamp': '2024-10-31T19:00:00',
#     'VL': '82',
#     'WLL': '93'}],
#   'L1N1': ['23.12851', '72.54742'],
#   'STATUS': False,
#   'TIMESTAMP': '2024-11-01T17:00:00',
#   'WLSU_NAME': 'WLSU_31'},
#  {'WLSU_ID': '21964',
#   'CLUSTER_ID': '6073',
#   'data_history': [{'AQI': '68',
#     'ISD': '38',
#     'SQI': '90',
#     'timestamp': '2024-10-31T23:00:00',
#     'VL': '94',
#     'WLL': '96'},
#    {'AQI': '123',
#     'ISD': '26',
#     'SQI': '93',
#     'timestamp': '2024-10-31T14:00:00',
#     'VL': '79',
#     'WLL': '93'},
#    {'AQI': '108',
#     'ISD': '41',
#     'SQI': '99',
#     'timestamp': '2024-11-01T14:00:00',
#     'VL': '86',
#     'WLL': '80'}],
#   'L1N1': ['23.1285', '72.54717'],
#   'STATUS': False,
#   'TIMESTAMP': '2024-10-31T17:00:00',
#   'WLSU_NAME': 'WLSU_38'},
#  {'WLSU_ID': '23299',
#   'CLUSTER_ID': '1085',
#   'data_history': [{'AQI': '131',
#     'ISD': '28',
#     'SQI': '88',
#     'timestamp': '2024-10-31T23:00:00',
#     'VL': '78',
#     'WLL': '88'},
#    {'AQI': '89',
#     'ISD': '41',
#     'SQI': '75',
#     'timestamp': '2024-10-31T19:00:00',
#     'VL': '100',
#     'WLL': '94'},
#    {'AQI': '69',
#     'ISD': '44',
#     'SQI': '71',
#     'timestamp': '2024-11-02T00:00:00',
#     'VL': '90',
#     'WLL': '80'}],
#   'L1N1': ['23.12851', '72.54678'],
#   'STATUS': False,
#   'TIMESTAMP': '2024-11-01T16:00:00',
#   'WLSU_NAME': 'WLSU_42'},
#  {'WLSU_ID': '62836',
#   'CLUSTER_ID': '2742',
#   'data_history': [{'AQI': '139',
#     'ISD': '27',
#     'SQI': '72',
#     'timestamp': '2024-11-01T03:00:00',
#     'VL': '98',
#     'WLL': '93'},
#    {'AQI': '102',
#     'ISD': '41',
#     'SQI': '74',
#     'timestamp': '2024-11-02T04:00:00',
#     'VL': '83',
#     'WLL': '89'},
#    {'AQI': '75',
#     'ISD': '25',
#     'SQI': '83',
#     'timestamp': '2024-11-01T08:00:00',
#     'VL': '83',
#     'WLL': '82'}],
#   'L1N1': ['23.12829', '72.54599'],
#   'STATUS': True,
#   'TIMESTAMP': '2024-11-01T01:00:00',
#   'WLSU_NAME': 'WLSU_54'},
#  {'WLSU_ID': '65132',
#   'CLUSTER_ID': '9253',
#   'data_history': [{'AQI': '44',
#     'ISD': '49',
#     'SQI': '92',
#     'timestamp': '2024-11-02T03:00:00',
#     'VL': '78',
#     'WLL': '88'},
#    {'AQI': '104',
#     'ISD': '24',
#     'SQI': '90',
#     'timestamp': '2024-11-02T03:00:00',
#     'VL': '78',
#     'WLL': '89'},
#    {'AQI': '148',
#     'ISD': '37',
#     'SQI': '94',
#     'timestamp': '2024-10-31T21:00:00',
#     'VL': '85',
#     'WLL': '81'}],
#   'L1N1': ['23.12824', '72.54244'],
#   'STATUS': True,
#   'TIMESTAMP': '2024-11-02T10:00:00',
#   'WLSU_NAME': 'WLSU_67'},
#  {'WLSU_ID': '76653',
#   'CLUSTER_ID': '8793',
#   'data_history': [{'AQI': '128',
#     'ISD': '26',
#     'SQI': '69',
#     'timestamp': '2024-10-31T20:00:00',
#     'VL': '93',
#     'WLL': '97'},
#    {'AQI': '105',
#     'ISD': '50',
#     'SQI': '99',
#     'timestamp': '2024-11-01T16:00:00',
#     'VL': '91',
#     'WLL': '91'},
#    {'AQI': '57',
#     'ISD': '24',
#     'SQI': '82',
#     'timestamp': '2024-11-02T00:00:00',
#     'VL': '95',
#     'WLL': '88'}],
#   'L1N1': ['23.12811', '72.5425'],
#   'STATUS': True,
#   'TIMESTAMP': '2024-10-31T23:00:00',
#   'WLSU_NAME': 'WLSU_75'},
#  {'WLSU_ID': '94916',
#   'CLUSTER_ID': '3490',
#   'data_history': [{'AQI': '121',
#     'ISD': '47',
#     'SQI': '65',
#     'timestamp': '2024-11-01T06:00:00',
#     'VL': '87',
#     'WLL': '97'},
#    {'AQI': '64',
#     'ISD': '42',
#     'SQI': '61',
#     'timestamp': '2024-11-02T07:00:00',
#     'VL': '91',
#     'WLL': '87'},
#    {'AQI': '60',
#     'ISD': '38',
#     'SQI': '82',
#     'timestamp': '2024-11-01T00:00:00',
#     'VL': '70',
#     'WLL': '92'}],
#   'L1N1': ['23.12839', '72.54744'],
#   'STATUS': False,
#   'TIMESTAMP': '2024-10-31T20:00:00',
#   'WLSU_NAME': 'WLSU_90'},
#  {'WLSU_ID': '70273',
#   'CLUSTER_ID': '3050',
#   'data_history': [{'AQI': '67',
#     'ISD': '50',
#     'SQI': '78',
#     'timestamp': '2024-11-01T06:00:00',
#     'VL': '85',
#     'WLL': '82'},
#    {'AQI': '122',
#     'ISD': '21',
#     'SQI': '64',
#     'timestamp': '2024-10-31T17:00:00',
#     'VL': '96',
#     'WLL': '81'},
#    {'AQI': '108',
#     'ISD': '32',
#     'SQI': '86',
#     'timestamp': '2024-10-31T14:00:00',
#     'VL': '91',
#     'WLL': '81'}],
#   'L1N1': ['23.12726', '72.54497'],
#   'STATUS': True,
#   'TIMESTAMP': '2024-11-01T11:00:00',
#   'WLSU_NAME': 'WLSU_88'},
#  {'WLSU_ID': '95268',
#   'CLUSTER_ID': '1405',
#   'data_history': [{'AQI': '121',
#     'ISD': '44',
#     'SQI': '72',
#     'timestamp': '2024-11-02T04:00:00',
#     'VL': '88',
#     'WLL': '90'},
#    {'AQI': '148',
#     'ISD': '35',
#     'SQI': '86',
#     'timestamp': '2024-11-01T07:00:00',
#     'VL': '84',
#     'WLL': '89'},
#    {'AQI': '145',
#     'ISD': '20',
#     'SQI': '71',
#     'timestamp': '2024-10-31T15:00:00',
#     'VL': '74',
#     'WLL': '97'}],
#   'L1N1': ['23.12784', '72.54599'],
#   'STATUS': False,
#   'TIMESTAMP': '2024-11-01T02:00:00',
#   'WLSU_NAME': 'WLSU_54'},
#  {'WLSU_ID': '36229',
#   'CLUSTER_ID': '8966',
#   'data_history': [{'AQI': '62',
#     'ISD': '37',
#     'SQI': '73',
#     'timestamp': '2024-10-31T15:00:00',
#     'VL': '87',
#     'WLL': '89'},
#    {'AQI': '139',
#     'ISD': '30',
#     'SQI': '89',
#     'timestamp': '2024-11-01T16:00:00',
#     'VL': '87',
#     'WLL': '87'},
#    {'AQI': '115',
#     'ISD': '37',
#     'SQI': '91',
#     'timestamp': '2024-11-02T11:00:00',
#     'VL': '93',
#     'WLL': '83'}],
#   'L1N1': ['23.12726', '72.54472'],
#   'STATUS': True,
#   'TIMESTAMP': '2024-11-01T17:00:00',
#   'WLSU_NAME': 'WLSU_35'},
#  {'WLSU_ID': '68836',
#   'CLUSTER_ID': '2689',
#   'data_history': [{'AQI': '97',
#     'ISD': '35',
#     'SQI': '80',
#     'timestamp': '2024-10-31T19:00:00',
#     'VL': '75',
#     'WLL': '99'},
#    {'AQI': '87',
#     'ISD': '45',
#     'SQI': '60',
#     'timestamp': '2024-11-01T13:00:00',
#     'VL': '99',
#     'WLL': '90'},
#    {'AQI': '60',
#     'ISD': '21',
#     'SQI': '67',
#     'timestamp': '2024-10-31T18:00:00',
#     'VL': '91',
#     'WLL': '93'}],
#   'L1N1': ['23.12726', '72.54409'],
#   'STATUS': False,
#   'TIMESTAMP': '2024-10-31T20:00:00',
#   'WLSU_NAME': 'WLSU_23'}]

# %%
from fastapi.testclient import TestClient
from shapely.geometry import Point
from datetime import datetime
from main import app
client = TestClient(app)

def insert_wlsu_between_coordinates(data: list):
    for i in data: 
        response = client.post("/wlsu/", json=i)
        if response.status_code == 200:
            print(f"WLSU inserted: {i['WLSU_ID']}")
        else:
            print(f"Failed to insert WLSU: {i['WLSU_ID']}, Status Code: {response.status_code}, Response: {response.json()}")
            break

# %%
insert_wlsu_between_coordinates(sample_data)
# Out:
# WLSU inserted: 25938
# WLSU inserted: 98446
# WLSU inserted: 99532
# WLSU inserted: 55286
# WLSU inserted: 98481
# WLSU inserted: 23892
# WLSU inserted: 75567
# WLSU inserted: 53224
# WLSU inserted: 56032
# WLSU inserted: 95840
# WLSU inserted: 21964
# WLSU inserted: 23299
# WLSU inserted: 62836
# WLSU inserted: 65132
# WLSU inserted: 76653
# WLSU inserted: 94916
# WLSU inserted: 70273
# WLSU inserted: 95268
# WLSU inserted: 36229
# WLSU inserted: 68836
